# %% [markdown]
# ### Vlada Data

# %%
print("Hello Worls!")
# Out:
# Hello Worls!

# %%
import pandas as pd

def clean_data(df):
    # Sort by column: 'Продано' (ascending)
    df = df.sort_values(['Продано'])
    return df

# Loaded variable 'df' from URI: /Users/vitaliydrugak/Documents/GitHub/business-report/milyi-ya-u-mamy_income-services_22_10_2024.xlsx
df = pd.read_excel(r'/Users/vitaliydrugak/Documents/GitHub/business-report/milyi-ya-u-mamy_income-services_22_10_2024.xlsx')

df_clean = clean_data(df.copy())
df_clean.head()
# Out:
#                Категорія  Продано  Дохід  Собівартість  Зарплата  Прибуток
# 129  Ботокс Підборіддя М        0    0.0             0       0.0       0.0
# 86                  Щоки        0    0.0             0       0.0       0.0
# 142   Парафінотерпія рук        0    0.0             0       0.0       0.0
# 85           Все обличчя        0    0.0             0       0.0       0.0
# 84       Класичне бікіні        0    0.0             0       0.0       0.0

# %%
import matplotlib.pyplot as plt

plt.scatter(df['Прибуток'], df['Категорія'])
plt.show()

# %% [markdown]
# ## Titanic Data

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


titanicData = pd.read_csv('titanic5.csv')

fig, axs = plt.subplots(ncols=2, figsize=(30,10))
sns.violinplot(x="Survived", y="Age", hue="Sex", data=titanicData, ax=axs[0])
# sns.pointplot(x="sibsp", y="Survived", hue="Sex", data=titanicData, ax=axs[1])
# sns.pointplot(x="parch", y="Survived", hue="Sex", data=titanicData, ax=axs[2])
sns.pointplot(x="Class", y="Survived", hue="Sex", data=titanicData, ax=axs[1])
# sns.violinplot(x="Survived", y="Cost", hue="Sex", data=titanicData, ax=axs[4])
# Out:
# <AxesSubplot:xlabel='Class', ylabel='Survived'>

# %%
titanicData.replace({'male': 1, 'female': 0}, inplace=True)
titanicData.corr().abs()[["Survived"]]
# Out:
#           Survived
# Name_ID   0.034887
# Sex       0.528693
# Age       0.032495
# Class     0.313359
# Survived  1.000000
# Age_F     0.039410
# sibsp     0.027825
# parch     0.082660
